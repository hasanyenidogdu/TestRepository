# %% [markdown]
# <a href="https://colab.research.google.com/github/hasanyenidogdu/TestRepository/blob/master/training-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Selam Dünya!')
print('Hasan\'ın Python Egzersizleri')
print('Python Öğreniyorum')
print(5+2)
print(5+3-2)
print(10/2)
print(3*(3+2))
print(4+1.2)
print("Üslü Sayılar")
print(2**5)
print(2**3**2)
print(9**(1/2))
print(8**(1/3))
print('*-_-_-Küsüratsız Bölme işlemi-_-_-*')
print(20//6)
print(10//4)
print('*--Eğer ki küsüratlı bölersek bu şekilde--*')
print(20/6)
print(10/4)
print('*-_-_-Bölme işleminden KALAN sayıyı bulma (Remainder - modulo operator) -_-_-*')
print(20 % 6)
print(1.25 % 0.5)
print(7%(5 // 2))
print('*--Egzersiz & Alıştırma--*')
print((3**2)//2)
print('*-_-_-Strings -_-_-*')
print('Sonya\'nın annesi: O\'nun bir melek olmasada. O\'nun çok tatlı bir çocuk olmasından bahsetti!')
print('Brian\'s mother: He\'s not an angel. He\'s a very naught boy!')
# Birden fazla satırı alt alta yazmaya ihtiyacımız varsa \n kullanarak tek satırda çoklu satır yazabiliriz.
print('Birinci \nİkinci \nÜçüncü')
# Burada tab dediğimiz sekme oluşturmaya yarar. Google Chrome'da ki sekmelerden aklımızda kalabilir.
print('Yeni Sekme \tYeni Sekme2 \tYeni Sekme3')
print("""bu
bir
multiline
text""")
('*-_-Concatenation (Birleştirme)-_-*')
print("Spam" + 'yumurtalar')
print("Spam " + 'yumurtalar')
# Burada 2 ayrı stringi topluyoruz ve sonuç 22. Burada yapılan işlem math değil string birleştirmedir.
print("2" + "2")
('*-_-String Operations-_-*')
# Burada stringi 3 sayısıyla çarptık ve stringin 3 kere tekrarlandığını görüyoruz.
print("flood" * 3)
# Burada 4 kere '2' stringini tekrarladığımız için sonuç: 2222
print(4 * '2')
#
# Variables (Değişkenlere) geçiş yapıyoruz..
print('*-_-_-Variables -_-_-*')
user_id = 1
user = "Admin"
user_age = 29
print('User ID:', user_id ,'\nUsername:',  user ,'\nAge:', user_age)
##################
x = 7
print(x)
print(x + 3)
print(x)
flood = "yumurta"
print(flood * 3)
# STRING e ekleme / düzeltme yapma
x = 123.456
print(x)

x = "Bu bir string"
print(x + "!")
# INPUT girdisi
print('Bir kullanıcı adı belirleyiniz')
k_adi = input()
print(k_adi)
print('Bir şifre belirleyiniz')
sifre = input()
print('Kullanıcı adı ve şifreniz belirlenmiştir.')
print(k_adi + '\n'+ sifre)
# Part 2 (girilen input'a ne için girdi girildiğini belirtme)
name = input('Adınızı yazınız: ')
print("Merhaba, " + name)
# Out:
# Selam Dünya!
# Hasan'ın Python Egzersizleri
# Python Öğreniyorum
# 7
# 6
# 5.0
# 15
# 5.2
# Üslü Sayılar
# 32
# 512
# 3.0
# 2.0
# *-_-_-Küsüratsız Bölme işlemi-_-_-*
# 3
# 2
# *--Eğer ki küsüratlı bölersek bu şekilde--*
# 3.3333333333333335
# 2.5
# *-_-_-Bölme işleminden KALAN sayıyı bulma (Remainder - modulo operator) -_-_-*
# 2
# 0.25
# 1
# *--Egzersiz & Alıştırma--*
# 4
# *-_-_-Strings -_-_-*
# Sonya'nın annesi: O'nun bir melek olmasada. O'nun çok tatlı bir çocuk olmasından bahsetti!
# Brian's mother: He's not an angel. He's a very naught boy!
# Birinci
# İkinci
# Üçüncü
# Yeni Sekme 	Yeni Sekme2 	Yeni Sekme3
# bu
# bir
# multiline
# text
# Spamyumurtalar
# Spam yumurtalar
# 22
# floodfloodflood
# 2222
# *-_-_-Variables -_-_-*
# User ID: 1
# Username: Admin
# Age: 29
# 7
# 10
# 7
# yumurtayumurtayumurta
# 123.456
# Bu bir string!
# Bir kullanıcı adı belirleyiniz
# admin
# admin
# Bir şifre belirleyiniz
# 1212
# Kullanıcı adı ve şifreniz belirlenmiştir.
# admin
# 1212
# ...
